# %%
import pandas as pd

# %%
df_origin = pd.read_excel("names.xlsx", sheet_name="名簿")
l = [2, 3, 6, 3, 6, 9, 8, 5, 8, 11, 9, 12, 3, 7, 1, 8, 7, 4, 2, 1, 6, 7, 4, 10, 3, 10, 5, 11, 1, 12, 6, 5, 4, 2, 2, 7, 4, 9, 5, 8, 12, 10, 1, 11]

# %%
df_origin
# Out:
#     対象 部・室  課  氏名  グループ分け1  グループ分け2  グループ分け3  グループ分け4  グループ分け5
# 0    1   a  a   A      5.0      1.0      1.0      1.0        9
# 1    1   a  a   B      NaN      NaN      NaN      NaN        5
# 2    0   a  a   C      6.0      6.0      3.0      8.0        3
# 3    1   a  a   D      1.0      2.0      8.0      0.0        9
# 4    1   b  b   E      NaN      NaN      NaN      NaN        8
# 5    1   b  b   F      4.0      0.0      5.0      7.0        1
# 6    1   b  b   G      5.0      8.0      7.0      6.0        1
# 7    1   b  b   H      1.0      3.0      0.0      0.0        6
# 8    1   c  c   I      0.0      9.0      7.0      0.0       10
# 9    1   c  c   J      3.0      4.0      6.0      5.0        8
# 10   1   c  c   K      2.0      6.0      1.0      9.0        1
# 11   1   c  c   L      8.0      2.0      2.0      1.0        0
# 12   1   c  c   M      6.0      8.0      9.0      4.0        7
# 13   1   c  c   N      7.0      5.0      5.0      4.0        4
# ...

# %%
final_list = []
for j,i in enumerate(df_origin["対象"]):
    if i == 0:
        l[j] = None

# %%
len(l)
# Out:
# 44

# %%
l
# Out:
# [2,
#  3,
#  None,
#  3,
#  6,
#  9,
#  8,
#  5,
#  8,
#  11,
#  9,
#  12,
#  3,
#  7,
#  1,
#  8,
#  7,
#  4,
#  2,
#  1,
#  6,
#  7,
#  4,
#  10,
#  3,
#  10,
#  5,
#  11,
#  1,
#  12,
#  6,
#  5,
#  4,
#  2,
#  2,
#  7,
#  4,
#  9,
#  5,
#  8,
#  12,
#  10,
#  1,
#  11]
